# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # Generator

# %%
RANDOM_SIZE = 100
IMG_DIM = 28
BATCH_SIZE = 100
EPSILON = 1e-3
LEARNING_RATE = 0.0002

z_dist = keras.Input(shape=(RANDOM_SIZE,),dtype=tf.float32,name='generator_input')
first_layer = keras.layers.Dense(256,activation = tf.nn.relu,name="first_layer_generator")(z_dist)
fake_pred = keras.layers.Dense(784,activation = tf.nn.sigmoid,name="second_layer_generator")(first_layer)
fake_img = keras.layers.Reshape((28,28),name="fake_img")(fake_pred)

generator = keras.Model(z_dist,fake_img)
generator.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_input (InputLayer) [(None, 100)]             0
# _________________________________________________________________
# first_layer_generator (Dense (None, 256)               25856
# _________________________________________________________________
# second_layer_generator (Dens (None, 784)               201488
# _________________________________________________________________
# fake_img (Reshape)           (None, 28, 28)            0
# =================================================================
# Total params: 227,344
# Trainable params: 227,344
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Discriminator

# %%
img = keras.Input(shape=(IMG_DIM,IMG_DIM),dtype=tf.float32,name='img_input')
flattened_img = keras.layers.Flatten()(img)
first_layer = keras.layers.Dense(256,activation = tf.nn.relu,name="first_layer_discriminator")(flattened_img)
prediction = keras.layers.Dense(1,activation = tf.nn.sigmoid,name="second_layer_discriminator")(first_layer)

discriminator = keras.Model(img,prediction)
discriminator.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# img_input (InputLayer)       [(None, 28, 28)]          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# first_layer_discriminator (D (None, 256)               200960
# _________________________________________________________________
# second_layer_discriminator ( (None, 1)                 257
# =================================================================
# Total params: 201,217
# Trainable params: 201,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Model

# %%
class GAN(keras.Model):
  
  def __init__(self,generator,discriminator,**kwargs):
    super(GAN, self).__init__(**kwargs)
    self.generator = generator
    self.discriminator = discriminator
    self.generator_loss_tracker = keras.metrics.Mean(name="generator_loss")
    self.discriminator_loss_tracker = keras.metrics.Mean(name="discriminator_loss")

  @property
  def metrics(self):
    return [
            self.generator_loss_tracker,
            self.discriminator_loss_tracker
    ]


  def train_step(self,data):
    
    z = np.random.uniform(-1,1,size=(BATCH_SIZE,RANDOM_SIZE))   
    
    with tf.GradientTape() as disc_tape:

      with tf.GradientTape() as gen_tape:
        
        
        
        fake_img = self.generator(z)
        
        fake_predic = self.discriminator(fake_img)

        
        generator_loss = - tf.reduce_mean(tf.math.log(fake_predic+EPSILON))

      real_predic = self.discriminator(data)
      
      discriminator_loss = tf.math.log(real_predic+EPSILON)+tf.math.log(1-fake_predic+EPSILON)
      
      discriminator_loss = - tf.reduce_mean(discriminator_loss)
     
    
    gen_grad = gen_tape.gradient(generator_loss,self.generator.trainable_weights)
    
    disc_grad = disc_tape.gradient(discriminator_loss,self.discriminator.trainable_weights)

   
    self.optimizer.apply_gradients(zip(disc_grad , self.discriminator.trainable_weights))
    self.optimizer.apply_gradients(zip(gen_grad , self.generator.trainable_weights))
    self.generator_loss_tracker.update_state(generator_loss)
    self.discriminator_loss_tracker.update_state(discriminator_loss)

    return {
            "generator_loss": self.generator_loss_tracker.result(),
            "discriminator_loss": self.discriminator_loss_tracker.result()
        }

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.fashion_mnist.load_data()

mnist_fashion = np.concatenate([x_train,x_test],axis=0)
mnist_fashion = mnist_fashion.astype('float64')/255

# %%
tf.optimizers.Adam(LEARNING_RATE)

# %%
model = GAN(generator,discriminator)
model.compile(optimizer=tf.optimizers.Adam(LEARNING_RATE))
model.fit(mnist_fashion,epochs=50, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 2.1412 - discriminator_loss: 0.7369
# Epoch 2/50
# 700/700 [==============================] - 12s 16ms/step - generator_loss: 2.1062 - discriminator_loss: 0.6640
# Epoch 3/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.5995 - discriminator_loss: 0.8852
# Epoch 4/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.5365 - discriminator_loss: 0.9466
# Epoch 5/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.4574 - discriminator_loss: 1.0036
# Epoch 6/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.4499 - discriminator_loss: 0.9946
# Epoch 7/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.4270 - discriminator_loss: 1.0568
# Epoch 8/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.4131 - discriminator_loss: 1.0577
# Epoch 9/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3043 - discriminator_loss: 1.1455
# Epoch 10/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3606 - discriminator_loss: 1.1079
# Epoch 11/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3159 - discriminator_loss: 1.1581
# Epoch 12/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2936 - discriminator_loss: 1.1986
# Epoch 13/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2725 - discriminator_loss: 1.2350
# Epoch 14/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.3011 - discriminator_loss: 1.1972
# Epoch 15/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2658 - discriminator_loss: 1.2016
# Epoch 16/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2973 - discriminator_loss: 1.1660
# Epoch 17/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2501 - discriminator_loss: 1.2305
# Epoch 18/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3241 - discriminator_loss: 1.1569
# Epoch 19/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3250 - discriminator_loss: 1.1247
# Epoch 20/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3271 - discriminator_loss: 1.1809
# Epoch 21/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3351 - discriminator_loss: 1.2163
# Epoch 22/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3112 - discriminator_loss: 1.1450
# Epoch 23/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2712 - discriminator_loss: 1.2201
# Epoch 24/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2755 - discriminator_loss: 1.2230
# Epoch 25/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2143 - discriminator_loss: 1.2382
# Epoch 26/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2336 - discriminator_loss: 1.2462
# Epoch 27/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.3042 - discriminator_loss: 1.2150
# Epoch 28/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2939 - discriminator_loss: 1.2197
# Epoch 29/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.3099 - discriminator_loss: 1.2280
# Epoch 30/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2314 - discriminator_loss: 1.2510
# Epoch 31/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2433 - discriminator_loss: 1.2970
# Epoch 32/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.2249 - discriminator_loss: 1.3289
# Epoch 33/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2671 - discriminator_loss: 1.2324
# Epoch 34/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2237 - discriminator_loss: 1.2531
# Epoch 35/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2410 - discriminator_loss: 1.1918
# Epoch 36/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1474 - discriminator_loss: 1.3134
# Epoch 37/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2228 - discriminator_loss: 1.2908
# Epoch 38/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2055 - discriminator_loss: 1.2775
# Epoch 39/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1950 - discriminator_loss: 1.3412
# Epoch 40/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2145 - discriminator_loss: 1.3277
# Epoch 41/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.2768 - discriminator_loss: 1.2288
# Epoch 42/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1901 - discriminator_loss: 1.3036
# Epoch 43/50
# 700/700 [==============================] - 12s 16ms/step - generator_loss: 1.2175 - discriminator_loss: 1.2863
# Epoch 44/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.1514 - discriminator_loss: 1.3511
# Epoch 45/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1896 - discriminator_loss: 1.3214
# Epoch 46/50
# 700/700 [==============================] - 12s 16ms/step - generator_loss: 1.2221 - discriminator_loss: 1.3270
# Epoch 47/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1311 - discriminator_loss: 1.4184
# Epoch 48/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1511 - discriminator_loss: 1.3797
# Epoch 49/50
# 700/700 [==============================] - 12s 17ms/step - generator_loss: 1.1234 - discriminator_loss: 1.3764
# Epoch 50/50
# 700/700 [==============================] - 11s 16ms/step - generator_loss: 1.1149 - discriminator_loss: 1.4225

# %%
def plot_generated(x=20,y=20):
  import matplotlib.pyplot as plt
  imgs = model.generator(np.random.uniform(-1,1,size=(x*y,RANDOM_SIZE)))
  imgs = imgs.numpy()
  figure = np.zeros(shape=(20*28,20*28),dtype=np.float32)
  for i in range(x):
    for j in range(y):
      figure[i*28:(i+1)*28,j*28:(j+1)*28] = imgs[i*y+j]
  
  plt.figure(figsize=(25,25))
  plt.imshow(figure,cmap="Greys_r")

plot_generated()
